# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import squarify
from sklearn.preprocessing import LabelEncoder

# %%
db=pd.read_csv('adult.csv')

# %%
db.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week         country  salary
# 0          2174             0              40   United-States   <=50K
# ...

# %%
db.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
db.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# country           0
# salary            0
# dtype: int64

# %%
db.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# country           object
# salary            object
# dtype: object

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  country         32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
salary = db['salary']

# %%
salary = db['salary'].value_counts(normalize=True)
round(salary * 100, 2).astype('str') + ' %'
# Out:
#  <=50K    75.92 %
#  >50K     24.08 %
# Name: salary, dtype: object

# %%
categorical = db.select_dtypes(include = ["object"]).keys()
categorical
# Out:
# Index(['workclass', 'education', 'marital-status', 'occupation',
#        'relationship', 'race', 'sex', 'country', 'salary'],
#       dtype='object')

# %%
Numerical = db.select_dtypes(include = ["int64"]).keys()
Numerical
# Out:
# Index(['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss',
#        'hours-per-week'],
#       dtype='object')

# %%
salary = db['salary'].value_counts()

plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(7, 5))
sns.barplot(salary.index, salary.values, palette='bright')
plt.title('Distribution of Salary', fontdict={ 'fontweight': 'bold'})
plt.xlabel('Salary', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.ylabel('Number of people', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.tick_params(labelsize=10)
plt.show()
# Out:
# C:\Users\ADITI AWASTHI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
age = db['age'].value_counts()

plt.figure(figsize=(10, 5))
plt.style.use('ggplot')
sns.distplot(db['age'], bins=15)
plt.title('Distribution of Age', fontdict={
          'fontname': 'Helvetica', 'fontsize': 15, 'fontweight': 'bold'})
plt.xlabel('Age', fontdict={'fontname': 'Helvetica', 'fontsize': 15})
plt.ylabel('Number of people', fontdict={
           'fontname': 'Helvetica', 'fontsize': 15})
plt.tick_params(labelsize=10)
plt.show()
# Out:
# C:\Users\ADITI AWASTHI\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# findfont: Font family ['Helvetica'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Helvetica'] not found. Falling back to DejaVu Sans.

# %%
edu_num = db['education-num'].value_counts()

plt.style.use('ggplot')
plt.figure(figsize=(10, 5))
sns.barplot(edu_num.index, edu_num.values, palette='colorblind')
plt.title('Distribution of Years of Education', fontdict={
          'fontname': 'Helvetica', 'fontsize': 15, 'fontweight': 'bold'})
plt.xlabel('Years of Education', fontdict={
           'fontname': 'Helvetica', 'fontsize': 15})
plt.ylabel('Number of people', fontdict={
           'fontname': 'Helvetica', 'fontsize': 15})
plt.tick_params(labelsize=12)
plt.show()
# Out:
# C:\Users\ADITI AWASTHI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
marital = db['marital-status'].value_counts()

plt.style.use('default')
plt.figure(figsize=(10, 7))
plt.pie(marital.values, labels=marital.index, startangle=10, explode=(
    0, 0.20, 0, 0, 0, 0, 0), shadow=True, autopct='%1.1f%%')
plt.title('Marital distribution', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.legend()
plt.legend(prop={'size': 7})
plt.axis('equal')
plt.show()

# %%
race = db['race'].value_counts()

plt.style.use('default')
plt.figure(figsize=(10, 7))
plt.pie(race.values, labels=race.index, startangle=10, explode=(
    0, 0.20, 0, 0, 0, 0, 0), shadow=True, autopct='%1.1f%%')
plt.title('Marital distribution', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.legend()
plt.legend(prop={'size': 7})
plt.axis('equal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-8898b71d7fc2> in <module>
#       3 plt.style.use('default')
#       4 plt.figure(figsize=(10, 7))
# ----> 5 plt.pie(race.values, labels=race.index, startangle=10, explode=(
#       6     0, 0.20, 0, 0, 0, 0, 0), shadow=True, autopct='%1.1f%%')
#       7 plt.title('Marital distribution', fontdict={
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2825         textprops=None, center=(0, 0), frame=False,
#    2826         rotatelabels=False, *, normalize=None, data=None):
# -> 2827     return gca().pie(
#    2828         x, explode=explode, labels=labels, colors=colors,
# ...

# %%
fig = plt.figure(figsize=(15,10))

sns.countplot('education', hue='salary', data=db)
plt.title('Distribution of educational degree along salary', fontdict={
          'fontname': 'Helvetica', 'fontsize': 15, 'fontweight': 'bold'})
plt.xlabel('Education & Salary', fontdict={
           'fontname': 'Helvetica', 'fontsize': 15})
plt.ylabel('Number of people', fontdict={
           'fontname': 'Helvetica', 'fontsize': 15})
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ADITI AWASTHI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# findfont: Font family ['Helvetica'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Helvetica'] not found. Falling back to DejaVu Sans.

# %%
fig = plt.figure(figsize=(15,10))

sns.countplot('sex', hue='salary', data=db)
plt.title('Distribution of Gender along salary', fontdict={
          'fontname': 'Helvetica', 'fontsize': 15, 'fontweight': 'bold'})
plt.xlabel('Gender & Salary', fontdict={
           'fontname': 'Helvetica', 'fontsize': 15})
plt.ylabel('Number of people', fontdict={
           'fontname': 'Helvetica', 'fontsize': 15})
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ADITI AWASTHI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fig = plt.figure(figsize=(15,10))

sns.countplot('hours-per-week', hue='salary', data=db)
plt.title('Distribution of hours-per-week along salary', fontdict={
          'fontname': 'Helvetica', 'fontsize': 15, 'fontweight': 'bold'})
plt.xlabel('hours-per-week & Salary', fontdict={
           'fontname': 'Helvetica', 'fontsize': 15})
plt.ylabel('Number of people', fontdict={
           'fontname': 'Helvetica', 'fontsize': 15})
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ADITI AWASTHI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.style.use('default')
plt.figure(figsize=(20, 7))
sns.countplot(db['age'], hue=db['salary'])
plt.title('Distribution of salary across Age', fontdict={
          'fontname': 'Monospace', 'fontsize': 20, 'fontweight': 'bold'})
plt.xlabel('Age', fontdict={'fontname': 'Monospace', 'fontsize': 15})
plt.ylabel('Number of people', fontdict={
           'fontname': 'Monospace', 'fontsize': 15})
plt.tick_params(labelsize=12)
plt.legend(loc=1, prop={'size': 15})
plt.show()
# Out:
# C:\Users\ADITI AWASTHI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
db.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week         country  salary
# 0          2174             0              40   United-States   <=50K
# ...

# %%
sns.pairplot(db)
plt.savefig('multi1.png')
plt.show()

# %%
corr = db.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(7, 5))
    ax = sns.heatmap(corr, mask=mask, vmax=.3, square=True,
                     annot=True, cmap='RdYlGn')
plt.savefig('multi2.png')
plt.show()

# %%
db = db.replace('?', np.nan)

# %%
col_with_nan_values=['workclass','occupation','country']

# %%
for i in col_with_nan_values:
    db[i].fillna(db[i].mode()[0], inplace=True)

# %%
for col in categorical:
        encoder = LabelEncoder()
        db[col] = encoder.fit_transform(db[col])

# %%
db.head()
# Out:
#    age  workclass  fnlwgt  education  education-num  marital-status  \
# 0   39          7   77516          9             13               4
# 1   50          6   83311          9             13               2
# 2   38          4  215646         11              9               0
# 3   53          4  234721          1              7               2
# 4   28          4  338409          9             13               2
#
#    occupation  relationship  race  sex  capital-gain  capital-loss  \
# 0           1             1     4    1          2174             0
# 1           4             0     4    1             0             0
# 2           6             1     4    1             0             0
# 3           6             0     2    1             0             0
# 4          10             5     2    0             0             0
#
#    hours-per-week  country  salary
# 0              40       39       0
# 1              13       39       0
# 2              40       39       0
# ...

# %%
db=db.drop(columns=["relationship","race","country"])

# %%
db.head()
# Out:
#    age  workclass  fnlwgt  education  education-num  marital-status  \
# 0   39          7   77516          9             13               4
# 1   50          6   83311          9             13               2
# 2   38          4  215646         11              9               0
# 3   53          4  234721          1              7               2
# 4   28          4  338409          9             13               2
#
#    occupation  sex  capital-gain  capital-loss  hours-per-week  salary
# 0           1    1          2174             0              40       0
# 1           4    1             0             0              13       0
# 2           6    1             0             0              40       0
# 3           6    1             0             0              40       0
# 4          10    0             0             0              40       0

# %%
X = db.drop('salary', axis=1)
Y = db['salary']

# %%
X
# Out:
#        age  workclass  fnlwgt  education  education-num  marital-status  \
# 0       39          7   77516          9             13               4
# 1       50          6   83311          9             13               2
# 2       38          4  215646         11              9               0
# 3       53          4  234721          1              7               2
# 4       28          4  338409          9             13               2
# ...    ...        ...     ...        ...            ...             ...
# 32556   27          4  257302          7             12               2
# 32557   40          4  154374         11              9               2
# 32558   58          4  151910         11              9               6
# 32559   22          4  201490         11              9               4
# 32560   52          5  287927         11              9               2
#
#        occupation  sex  capital-gain  capital-loss  hours-per-week
# ...

# %%
Y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32556    0
# 32557    1
# 32558    0
# 32559    0
# 32560    1
# Name: salary, Length: 32561, dtype: int32

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.30, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
randomForestClassifier = RandomForestClassifier(random_state=42)

# %%
Y_pred_randomForestClassifier = randomForestClassifier.predict(X_test)

# %%
predict=randomForestClassifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
print('Random Forest Classifier:')
print('Accuracy score:', round(accuracy_score(y_test, Y_pred_randomForestClassifier)* 100, 2))
# Out:
# Random Forest Classifier:
# Accuracy score: 85.52

# %%
import pickle
file = open('randomForestClassifier.pkl', 'wb')

pickle.dump(randomForestClassifier, file)
